# %%
import urllib.request
import time
import json
nextBikeUrl = 'https://api.nextbike.net/maps/nextbike-live.json?city=14'

# %%
page = urllib.request.urlopen(nextBikeUrl)
data = page.read()

"""Process the crawled information."""
dataString = data.decode('utf8').replace("'", '"')
dataJson = json.loads(dataString)

# %%
bikedata = dataJson["countries"][0]["cities"][0]["places"]

# %%
bikedata
# Out:
# [{'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.957410536847,
#   'lng': 7.0119494627215,
#   'maintenance': False,
#   'name': 'Bahnhof Mühlheim ',
#   'number': 4812,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 22756},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.9429485,
#   'lng': 6.958015,
#   'maintenance': False,
#   'name': 'Hauptbahnhof',
#   'number': 4826,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 35409},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 9523,
#     'electric_lock': True,
#     'number': '21362',
#     'state': 'ok'}],
#   'bike_numbers': '21362',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9882439,
#   'lng': 6.9635421,
#   'maintenance': False,
#   'name': 'BIKE 21362',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 359355},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5234,
#     'electric_lock': True,
#     'number': '21128',
#     'state': 'ok'}],
#   'bike_numbers': '21128',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9046623,
#   'lng': 6.915262,
#   'maintenance': False,
#   'name': 'BIKE 21128',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 359411},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6104,
#     'electric_lock': True,
#     'number': '21729',
#     'state': 'ok'}],
#   'bike_numbers': '21729',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9924845,
#   'lng': 6.9589231,
#   'maintenance': False,
#   'name': 'BIKE 21729',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 367091},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 7745,
#     'electric_lock': True,
#     'number': '21065',
#     'state': 'ok'}],
#   'bike_numbers': '21065',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9543549,
#   'lng': 6.8909351,
#   'maintenance': False,
#   'name': 'BIKE 21065',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 379211},
#  {'address': 'Kalscheurer Weg 16',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 10934,
#     'electric_lock': True,
#     'number': '21081',
#     'state': 'ok'}],
#   'bike_numbers': '21081',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.903997468328,
#   'lng': 6.9380663663904,
#   'maintenance': False,
#   'name': 'BIKE 21081',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 395675},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6931,
#     'electric_lock': True,
#     'number': '21717',
#     'state': 'ok'}],
#   'bike_numbers': '21717',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9542226,
#   'lng': 6.8892625,
#   'maintenance': False,
#   'name': 'BIKE 21717',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 416549},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11311,
#     'electric_lock': True,
#     'number': '21900',
#     'state': 'ok'}],
#   'bike_numbers': '21900',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.920303,
#   'lng': 6.9019882,
#   'maintenance': False,
#   'name': 'BIKE 21900',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 423992},
#  {'address': 'Bonner Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10725,
#     'electric_lock': True,
#     'number': '21541',
#     'state': 'ok'}],
#   'bike_numbers': '21541',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.905786163391,
#   'lng': 6.9639362709462,
#   'maintenance': False,
#   'name': 'BIKE 21541',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 426062},
#  {'address': None,
#   'bike': False,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6145,
#     'electric_lock': True,
#     'number': '21269',
#     'state': 'ok'},
#    {'active': True,
#     'bike_type': 15,
#     'boardcomputer': 8834,
#     'electric_lock': True,
#     'number': '21908',
#     'state': 'ok'}],
#   'bike_numbers': '21269,21908',
#   'bike_racks': 0,
#   'bike_types': {'15': 2},
#   'bikes': 2,
#   'free_racks': 0,
#   'lat': 50.938831373138,
#   'lng': 6.9062697887421,
#   'maintenance': False,
#   'name': 'KVB Hauptverwaltung',
#   'number': 4821,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 430479},
#  {'address': 'Militärringstraße / Junkersdorfer Str. ',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 6865,
#     'electric_lock': True,
#     'number': '21084',
#     'state': 'ok'}],
#   'bike_numbers': '21084',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.934139,
#   'lng': 6.88621,
#   'maintenance': False,
#   'name': 'BIKE 21084',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 498138},
#  {'address': 'Trankgasse 11',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6668,
#     'electric_lock': True,
#     'number': '21934',
#     'state': 'ok'}],
#   'bike_numbers': '21934',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.943097474445,
#   'lng': 6.9597195335555,
#   'maintenance': False,
#   'name': 'BIKE 21934',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 621084},
#  {'address': 'Weißenburgstraße 68',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11528,
#     'electric_lock': True,
#     'number': '22130',
#     'state': 'ok'}],
#   'bike_numbers': '22130',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.954056215,
#   'lng': 6.9615483915,
#   'maintenance': False,
#   'name': 'BIKE 22130',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 656408},
#  {'address': 'Corkstraße 20',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 7023,
#     'electric_lock': True,
#     'number': '21507',
#     'state': 'ok'}],
#   'bike_numbers': '21507',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.941255695,
#   'lng': 6.997333242,
#   'maintenance': False,
#   'name': 'BIKE 21507',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 660074},
#  {'address': 'Schanzenstraße 28',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 6731,
#     'electric_lock': True,
#     'number': '21184',
#     'state': 'ok'}],
#   'bike_numbers': '21184',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.967753835,
#   'lng': 7.0110225,
#   'maintenance': False,
#   'name': 'BIKE 21184',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 665814},
#  {'address': 'Subbelrather Straße 168',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6999,
#     'electric_lock': True,
#     'number': '21820',
#     'state': 'ok'}],
#   'bike_numbers': '21820',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.952148715,
#   'lng': 6.925463,
#   'maintenance': False,
#   'name': 'BIKE 21820',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 666941},
#  {'address': 'Christian-Sünner-Straße 8',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6450,
#     'electric_lock': True,
#     'number': '21901',
#     'state': 'ok'}],
#   'bike_numbers': '21901',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9353388125,
#   'lng': 7.0090627835,
#   'maintenance': False,
#   'name': 'BIKE 21901',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 672751},
#  {'address': 'Neumarkt 39',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6362,
#     'electric_lock': True,
#     'number': '22073',
#     'state': 'ok'}],
#   'bike_numbers': '22073',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9355727,
#   'lng': 6.946494017,
#   'maintenance': False,
#   'name': 'BIKE 22073',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 674800},
#  {'address': 'Mommsenstraße 2',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 6960,
#     'electric_lock': True,
#     'number': '22286',
#     'state': 'ok'}],
#   'bike_numbers': '22286',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.917758675,
#   'lng': 6.914463783,
#   'maintenance': False,
#   'name': 'BIKE 22286',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 692759},
#  {'address': 'Blankenheimer Straße 56',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5358,
#     'electric_lock': True,
#     'number': '22164',
#     'state': 'ok'}],
#   'bike_numbers': '22164',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91838918,
#   'lng': 6.9184592085,
#   'maintenance': False,
#   'name': 'BIKE 22164',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 698964},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.930656880252,
#   'lng': 6.9406342506409,
#   'maintenance': False,
#   'name': 'Zülpicher Platz',
#   'number': 4824,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 746518},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.935924149905,
#   'lng': 6.9476187229156,
#   'maintenance': False,
#   'name': 'Neumarkt',
#   'number': 4822,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 774641},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.928158268407,
#   'lng': 6.9282531738281,
#   'maintenance': False,
#   'name': 'Uni Köln',
#   'number': 4823,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1079530},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10184,
#     'electric_lock': True,
#     'number': '22017',
#     'state': 'ok'}],
#   'bike_numbers': '22017',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9605849,
#   'lng': 6.9793474,
#   'maintenance': False,
#   'name': 'BIKE 22017',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 1458107},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6035,
#     'electric_lock': True,
#     'number': '22010',
#     'state': 'ok'}],
#   'bike_numbers': '22010',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9558228,
#   'lng': 7.0069057,
#   'maintenance': False,
#   'name': 'BIKE 22010',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 1462261},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11489,
#     'electric_lock': True,
#     'number': '22348',
#     'state': 'ok'}],
#   'bike_numbers': '22348',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.924287,
#   'lng': 6.8977544,
#   'maintenance': False,
#   'name': 'BIKE 22348',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 1542629},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.935362967283,
#   'lng': 6.9611263275146,
#   'maintenance': False,
#   'name': 'Maritim ',
#   'number': 4827,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 1546312},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.950526039316,
#   'lng': 6.9577574729919,
#   'maintenance': False,
#   'name': 'Ebertplatz',
#   'number': 4828,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1546319},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94376647545,
#   'lng': 6.9335317611694,
#   'maintenance': False,
#   'name': 'Hans-Böckler-Platz',
#   'number': 4832,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1778321},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.940061817528,
#   'lng': 6.975063085556,
#   'maintenance': False,
#   'name': 'Bahnhof Deutz',
#   'number': 4831,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1979532},
#  {'address': None,
#   'bike': False,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10922,
#     'electric_lock': True,
#     'number': '21441',
#     'state': 'ok'},
#    {'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5957,
#     'electric_lock': True,
#     'number': '21325',
#     'state': 'ok'}],
#   'bike_numbers': '21441,21325',
#   'bike_racks': 0,
#   'bike_types': {'15': 1, 'undefined': 1},
#   'bikes': 2,
#   'free_racks': 0,
#   'lat': 50.943830695931,
#   'lng': 6.95955991745,
#   'maintenance': False,
#   'name': 'Breslauer Platz',
#   'number': 4834,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1979551},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.92917936822,
#   'lng': 6.9572532176971,
#   'maintenance': False,
#   'name': 'Severinsstrasse',
#   'number': 4846,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1979640},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.961764,
#   'lng': 7.004147,
#   'maintenance': False,
#   'name': 'Wienerplatz',
#   'number': 4835,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 1979653},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.944959609907,
#   'lng': 6.9720053672791,
#   'maintenance': False,
#   'name': 'RTL Picassoplatz',
#   'number': 4847,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 2049483},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.927127002468,
#   'lng': 6.9325232505798,
#   'maintenance': False,
#   'name': 'Uni Mensa',
#   'number': 4849,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 2193550},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.921649075569,
#   'lng': 6.9593775272369,
#   'maintenance': False,
#   'name': 'Chlodwigplatz',
#   'number': 4836,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 2464901},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.919538887205,
#   'lng': 6.9666194915771,
#   'maintenance': False,
#   'name': 'TH Köln Südstadt',
#   'number': 4837,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 2802298},
#  {'address': 'Neumarkt 2',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5668,
#     'electric_lock': True,
#     'number': '21045',
#     'state': 'ok'}],
#   'bike_numbers': '21045',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93625425,
#   'lng': 6.948863033,
#   'maintenance': False,
#   'name': 'BIKE 21045',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 2881284},
#  {'address': 'Derfflingerstraße 2',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 12061,
#     'electric_lock': True,
#     'number': '21249',
#     'state': 'ok'}],
#   'bike_numbers': '21249',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98018422,
#   'lng': 6.9483906,
#   'maintenance': False,
#   'name': 'BIKE 21249',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 2926994},
#  {'address': 'Rurstraße 19',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10274,
#     'electric_lock': True,
#     'number': '22285',
#     'state': 'ok'}],
#   'bike_numbers': '22285',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.921721,
#   'lng': 6.914649767,
#   'maintenance': False,
#   'name': 'BIKE 22285',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 2961715},
#  {'address': 'Severinstraße 40',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 7004,
#     'electric_lock': True,
#     'number': '22043',
#     'state': 'ok'}],
#   'bike_numbers': '22043',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.92374318,
#   'lng': 6.959026283,
#   'maintenance': False,
#   'name': 'BIKE 22043',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 2977701},
#  {'address': 'Neumarkt 41',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5855,
#     'electric_lock': True,
#     'number': '22357',
#     'state': 'ok'}],
#   'bike_numbers': '22357',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93560048,
#   'lng': 6.946411383,
#   'maintenance': False,
#   'name': 'BIKE 22357',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 2981211},
#  {'address': 'Mathiaskirchplatz 16',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11423,
#     'electric_lock': True,
#     'number': '22365',
#     'state': 'ok'}],
#   'bike_numbers': '22365',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.90949843,
#   'lng': 6.965153267,
#   'maintenance': False,
#   'name': 'BIKE 22365',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3018779},
#  {'address': 'Maybachstraße 36',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 8687,
#     'electric_lock': True,
#     'number': '21615',
#     'state': 'ok'}],
#   'bike_numbers': '21615',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94745395,
#   'lng': 6.9460106,
#   'maintenance': False,
#   'name': 'BIKE 21615',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3041159},
#  {'address': 'Remscheider Straße 117',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10900,
#     'electric_lock': True,
#     'number': '22094',
#     'state': 'ok'}],
#   'bike_numbers': '22094',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94624658,
#   'lng': 7.0115709,
#   'maintenance': False,
#   'name': 'BIKE 22094',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3066243},
#  {'address': 'Aachener Straße 403a',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10117,
#     'electric_lock': True,
#     'number': '22211',
#     'state': 'ok'}],
#   'bike_numbers': '22211',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.936897,
#   'lng': 6.910086667,
#   'maintenance': False,
#   'name': 'BIKE 22211',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3121708},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.927174339766,
#   'lng': 6.9037592411041,
#   'maintenance': False,
#   'name': 'Leonardo Royal Hotel',
#   'number': 4840,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 3176060},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.937032972765,
#   'lng': 6.9836461544037,
#   'maintenance': False,
#   'name': 'Hotel Stadtpalais',
#   'number': 4839,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 3176087},
#  {'address': 'Am Pistorhof 11',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5650,
#     'electric_lock': True,
#     'number': '21394',
#     'state': 'ok'}],
#   'bike_numbers': '21394',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96529737,
#   'lng': 6.909192517,
#   'maintenance': False,
#   'name': 'BIKE 21394',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3295593},
#  {'address': 'Margaretastraße 5',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6399,
#     'electric_lock': True,
#     'number': '21443',
#     'state': 'ok'}],
#   'bike_numbers': '21443',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96774048,
#   'lng': 6.907253017,
#   'maintenance': False,
#   'name': 'BIKE 21443',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 3494355},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.947031467523,
#   'lng': 6.9453978538513,
#   'maintenance': False,
#   'name': 'Motel One Mediapark',
#   'number': 4838,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': 'free',
#   'uid': 4078912},
#  {'address': None,
#   'bike': False,
#   'bike_list': [],
#   'bike_numbers': [],
#   'bike_racks': 0,
#   'bike_types': [],
#   'bikes': 0,
#   'free_racks': 0,
#   'lat': 50.93170497246,
#   'lng': 6.9544583559036,
#   'maintenance': False,
#   'name': 'Motel One Waidmarkt',
#   'number': 4850,
#   'place_type': '0',
#   'rack_locks': False,
#   'spot': True,
#   'terminal_type': '',
#   'uid': 4078954},
#  {'address': 'Steinkaulerstraße 3',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5902,
#     'electric_lock': True,
#     'number': '21393',
#     'state': 'ok'}],
#   'bike_numbers': '21393',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97555643,
#   'lng': 7.01423205,
#   'maintenance': False,
#   'name': 'BIKE 21393',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5204275},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5868,
#     'electric_lock': True,
#     'number': '21783',
#     'state': 'ok'}],
#   'bike_numbers': '21783',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98289387,
#   'lng': 6.873472467,
#   'maintenance': False,
#   'name': 'BIKE 21783',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5221329},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10047,
#     'electric_lock': True,
#     'number': '21814',
#     'state': 'ok'}],
#   'bike_numbers': '21814',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97214685,
#   'lng': 6.99602215,
#   'maintenance': False,
#   'name': 'BIKE 21814',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5244001},
#  {'address': 'Wilhelm-Leuschner-Straße 27',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 12855,
#     'electric_lock': True,
#     'number': '21114',
#     'state': 'ok'}],
#   'bike_numbers': '21114',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.99069203,
#   'lng': 6.914511617,
#   'maintenance': False,
#   'name': 'BIKE 21114',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5269948},
#  {'address': 'Unterer Komarweg',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5225,
#     'electric_lock': True,
#     'number': '22234',
#     'state': 'ok'}],
#   'bike_numbers': '22234',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.89982557,
#   'lng': 6.921413867,
#   'maintenance': False,
#   'name': 'BIKE 22234',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5352008},
#  {'address': 'Longericher Straße 205',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9996,
#     'electric_lock': True,
#     'number': '21813',
#     'state': 'ok'}],
#   'bike_numbers': '21813',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98202305,
#   'lng': 6.9202249,
#   'maintenance': False,
#   'name': 'BIKE 21813',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5384940},
#  {'address': 'Longericher Straße 212',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 13259,
#     'electric_lock': True,
#     'number': '21555',
#     'state': 'ok'}],
#   'bike_numbers': '21555',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98349295,
#   'lng': 6.918312083,
#   'maintenance': False,
#   'name': 'BIKE 21555',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5409060},
#  {'address': 'Auenweg',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5713,
#     'electric_lock': True,
#     'number': '21921',
#     'state': 'ok'}],
#   'bike_numbers': '21921',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94985432,
#   'lng': 6.98352385,
#   'maintenance': False,
#   'name': 'BIKE 21921',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5433085},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5861,
#     'electric_lock': True,
#     'number': '21162',
#     'state': 'ok'}],
#   'bike_numbers': '21162',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96630985,
#   'lng': 6.991203983,
#   'maintenance': False,
#   'name': 'BIKE 21162',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5447920},
#  {'address': 'Johannes-Dech-Straße 28',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5451,
#     'electric_lock': True,
#     'number': '21301',
#     'state': 'ok'}],
#   'bike_numbers': '21301',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9981596,
#   'lng': 6.92009365,
#   'maintenance': False,
#   'name': 'BIKE 21301',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5453955},
#  {'address': 'Franz-Kremer-Allee 1',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6675,
#     'electric_lock': True,
#     'number': '22048',
#     'state': 'ok'}],
#   'bike_numbers': '22048',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.90709347,
#   'lng': 6.905137533,
#   'maintenance': False,
#   'name': 'BIKE 22048',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5456599},
#  {'address': 'Arminiusstraße 8',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 7424,
#     'electric_lock': True,
#     'number': '21489',
#     'state': 'ok'}],
#   'bike_numbers': '21489',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93522455,
#   'lng': 6.971988867,
#   'maintenance': False,
#   'name': 'BIKE 21489',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5459900},
#  {'address': 'Zeisigweg 4',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5581,
#     'electric_lock': True,
#     'number': '21307',
#     'state': 'ok'}],
#   'bike_numbers': '21307',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95759555,
#   'lng': 6.871638267,
#   'maintenance': False,
#   'name': 'BIKE 21307',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5468159},
#  {'address': 'Deutz-Mülheimer Straße 149',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10116,
#     'electric_lock': True,
#     'number': '21028',
#     'state': 'ok'}],
#   'bike_numbers': '21028',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9537628,
#   'lng': 6.9909488,
#   'maintenance': False,
#   'name': 'BIKE 21028',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5469094},
#  {'address': 'Buchfinkenweg 43',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5896,
#     'electric_lock': True,
#     'number': '22229',
#     'state': 'ok'}],
#   'bike_numbers': '22229',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95247017,
#   'lng': 6.8838142,
#   'maintenance': False,
#   'name': 'BIKE 22229',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5474696},
#  {'address': 'Höninger Weg',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10129,
#     'electric_lock': True,
#     'number': '21487',
#     'state': 'ok'}],
#   'bike_numbers': '21487',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.89936792,
#   'lng': 6.9205382,
#   'maintenance': False,
#   'name': 'BIKE 21487',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5475743},
#  {'address': 'Bunsenstraße 18',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 11500,
#     'electric_lock': True,
#     'number': '21219',
#     'state': 'ok'}],
#   'bike_numbers': '21219',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95353507,
#   'lng': 7.00567305,
#   'maintenance': False,
#   'name': 'BIKE 21219',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5479095},
#  {'address': 'Remscheider Straße 121',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10592,
#     'electric_lock': True,
#     'number': '22142',
#     'state': 'ok'}],
#   'bike_numbers': '22142',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94681293,
#   'lng': 7.012102433,
#   'maintenance': False,
#   'name': 'BIKE 22142',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5480689},
#  {'address': 'Brügelmannstraße 7',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 4511,
#     'electric_lock': True,
#     'number': '22199',
#     'state': 'ok'}],
#   'bike_numbers': '22199',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94378347,
#   'lng': 6.9870202,
#   'maintenance': False,
#   'name': 'BIKE 22199',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5481960},
#  {'address': 'Vogelsanger Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5502,
#     'electric_lock': True,
#     'number': '21061',
#     'state': 'ok'}],
#   'bike_numbers': '21061',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95458337,
#   'lng': 6.892385683,
#   'maintenance': False,
#   'name': 'BIKE 21061',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5485071},
#  {'address': 'Fröbelstraße 1',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10595,
#     'electric_lock': True,
#     'number': '21928',
#     'state': 'ok'}],
#   'bike_numbers': '21928',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.99803785,
#   'lng': 6.870206667,
#   'maintenance': False,
#   'name': 'BIKE 21928',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5487448},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5719,
#     'electric_lock': True,
#     'number': '22163',
#     'state': 'ok'}],
#   'bike_numbers': '22163',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97463145,
#   'lng': 7.01469935,
#   'maintenance': False,
#   'name': 'BIKE 22163',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5491266},
#  {'address': 'Besselstraße 37',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10461,
#     'electric_lock': True,
#     'number': '21895',
#     'state': 'ok'}],
#   'bike_numbers': '21895',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95294527,
#   'lng': 7.007982117,
#   'maintenance': False,
#   'name': 'BIKE 21895',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5491453},
#  {'address': 'Hugo-Junkers-Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10790,
#     'electric_lock': True,
#     'number': '22185',
#     'state': 'ok'}],
#   'bike_numbers': '22185',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98966465,
#   'lng': 6.907396483,
#   'maintenance': False,
#   'name': 'BIKE 22185',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5491922},
#  {'address': 'De-Vries-Straße 17',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 9981,
#     'electric_lock': True,
#     'number': '21148',
#     'state': 'ok'}],
#   'bike_numbers': '21148',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96169292,
#   'lng': 6.966162383,
#   'maintenance': False,
#   'name': 'BIKE 21148',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5506439},
#  {'address': 'Immendorfer Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11450,
#     'electric_lock': True,
#     'number': '22341',
#     'state': 'ok'}],
#   'bike_numbers': '22341',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.88901407,
#   'lng': 6.908910933,
#   'maintenance': False,
#   'name': 'BIKE 22341',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5507247},
#  {'address': 'Am Verteilerkreis',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10447,
#     'electric_lock': True,
#     'number': '21544',
#     'state': 'ok'}],
#   'bike_numbers': '21544',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.89223117,
#   'lng': 6.96645135,
#   'maintenance': False,
#   'name': 'BIKE 21544',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5507548},
#  {'address': 'Adam-Stegerwald-Straße 19',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 6182,
#     'electric_lock': True,
#     'number': '21947',
#     'state': 'ok'}],
#   'bike_numbers': '21947',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95005032,
#   'lng': 6.992153783,
#   'maintenance': False,
#   'name': 'BIKE 21947',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5512656},
#  {'address': 'Merkenicher Straße 75',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5720,
#     'electric_lock': True,
#     'number': '21871',
#     'state': 'ok'}],
#   'bike_numbers': '21871',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98472438,
#   'lng': 6.96548945,
#   'maintenance': False,
#   'name': 'BIKE 21871',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5513257},
#  {'address': 'Rheinparkweg',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6683,
#     'electric_lock': True,
#     'number': '21577',
#     'state': 'ok'}],
#   'bike_numbers': '21577',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94487402,
#   'lng': 6.972157967,
#   'maintenance': False,
#   'name': 'BIKE 21577',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5516396},
#  {'address': 'Gelsenkirchener Straße 29',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9494,
#     'electric_lock': True,
#     'number': '21858',
#     'state': 'ok'}],
#   'bike_numbers': '21858',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97187252,
#   'lng': 6.963981383,
#   'maintenance': False,
#   'name': 'BIKE 21858',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5517488},
#  {'address': 'Longericher Straße 212',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6032,
#     'electric_lock': True,
#     'number': '21056',
#     'state': 'ok'}],
#   'bike_numbers': '21056',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98320718,
#   'lng': 6.918151817,
#   'maintenance': False,
#   'name': 'BIKE 21056',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5518501},
#  {'address': 'Militärringstraße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9617,
#     'electric_lock': True,
#     'number': '22123',
#     'state': 'ok'}],
#   'bike_numbers': '22123',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.90450787,
#   'lng': 6.914878217,
#   'maintenance': False,
#   'name': 'BIKE 22123',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5520884},
#  {'address': 'Stockholmer Allee 1',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5511,
#     'electric_lock': True,
#     'number': '22156',
#     'state': 'ok'}],
#   'bike_numbers': '22156',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 51.0237145,
#   'lng': 6.903552533,
#   'maintenance': False,
#   'name': 'BIKE 22156',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5521755},
#  {'address': 'Erlenhofstraße 2',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 10869,
#     'electric_lock': True,
#     'number': '21119',
#     'state': 'ok'}],
#   'bike_numbers': '21119',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98284908,
#   'lng': 6.961665933,
#   'maintenance': False,
#   'name': 'BIKE 21119',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5522076},
#  {'address': 'Schanzenstraße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5357,
#     'electric_lock': True,
#     'number': '22250',
#     'state': 'ok'}],
#   'bike_numbers': '22250',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9668232,
#   'lng': 7.013470883,
#   'maintenance': False,
#   'name': 'BIKE 22250',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5522105},
#  {'address': 'Carl-Schurz-Straße 9',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9143,
#     'electric_lock': True,
#     'number': '22162',
#     'state': 'ok'}],
#   'bike_numbers': '22162',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.92379335,
#   'lng': 6.900287517,
#   'maintenance': False,
#   'name': 'BIKE 22162',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5526208},
#  {'address': 'Marienburger Straße 4',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5211,
#     'electric_lock': True,
#     'number': '21879',
#     'state': 'ok'}],
#   'bike_numbers': '21879',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.90294748,
#   'lng': 6.9801742,
#   'maintenance': False,
#   'name': 'BIKE 21879',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5526228},
#  {'address': 'Robert-Perthel-Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5640,
#     'electric_lock': True,
#     'number': '21754',
#     'state': 'ok'}],
#   'bike_numbers': '21754',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97722937,
#   'lng': 6.9213039,
#   'maintenance': False,
#   'name': 'BIKE 21754',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5527832},
#  {'address': 'Sebastianstraße 75',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5377,
#     'electric_lock': True,
#     'number': '21550',
#     'state': 'ok'}],
#   'bike_numbers': '21550',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.98699327,
#   'lng': 6.959960033,
#   'maintenance': False,
#   'name': 'BIKE 21550',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5530911},
#  {'address': 'Peter-Michels-Straße 27',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10478,
#     'electric_lock': True,
#     'number': '21892',
#     'state': 'ok'}],
#   'bike_numbers': '21892',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97145542,
#   'lng': 6.9138474,
#   'maintenance': False,
#   'name': 'BIKE 21892',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5531074},
#  {'address': 'Höninger Weg',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10159,
#     'electric_lock': True,
#     'number': '22376',
#     'state': 'ok'}],
#   'bike_numbers': '22376',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.89908947,
#   'lng': 6.920550383,
#   'maintenance': False,
#   'name': 'BIKE 22376',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5531242},
#  {'address': 'Nürnberger Straße 39',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5175,
#     'electric_lock': True,
#     'number': '21134',
#     'state': 'ok'}],
#   'bike_numbers': '21134',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93913122,
#   'lng': 7.024548717,
#   'maintenance': False,
#   'name': 'BIKE 21134',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5531479},
#  {'address': 'Boltensternstraße 120',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5117,
#     'electric_lock': True,
#     'number': '21140',
#     'state': 'ok'}],
#   'bike_numbers': '21140',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.97386588,
#   'lng': 6.9757094,
#   'maintenance': False,
#   'name': 'BIKE 21140',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5532180},
#  {'address': 'Fabriciusstraße 14',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5274,
#     'electric_lock': True,
#     'number': '21442',
# ...
#     'bike_type': 15,
#     'boardcomputer': 10845,
#     'electric_lock': True,
#     'number': '21762',
#     'state': 'ok'}],
#   'bike_numbers': '21762',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94764748,
#   'lng': 6.925212833,
#   'maintenance': False,
#   'name': 'BIKE 21762',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575737},
#  {'address': 'Heumarkt',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10484,
#     'electric_lock': True,
#     'number': '21824',
#     'state': 'ok'}],
#   'bike_numbers': '21824',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93552565,
#   'lng': 6.96050115,
#   'maintenance': False,
#   'name': 'BIKE 21824',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575738},
#  {'address': 'Schönsteinstraße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10891,
#     'electric_lock': True,
#     'number': '22235',
#     'state': 'ok'}],
#   'bike_numbers': '22235',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95153622,
#   'lng': 6.91553175,
#   'maintenance': False,
#   'name': 'BIKE 22235',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575740},
#  {'address': 'Remscheider Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10707,
#     'electric_lock': True,
#     'number': '22283',
#     'state': 'ok'}],
#   'bike_numbers': '22283',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94460577,
#   'lng': 7.0059564,
#   'maintenance': False,
#   'name': 'BIKE 22283',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575765},
#  {'address': 'Stadtwaldgürtel 27',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 7467,
#     'electric_lock': True,
#     'number': '21018',
#     'state': 'ok'}],
#   'bike_numbers': '21018',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93053213,
#   'lng': 6.9076159,
#   'maintenance': False,
#   'name': 'BIKE 21018',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575766},
#  {'address': 'Höninger Weg 53',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6020,
#     'electric_lock': True,
#     'number': '21420',
#     'state': 'ok'}],
#   'bike_numbers': '21420',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91902343,
#   'lng': 6.9407887,
#   'maintenance': False,
#   'name': 'BIKE 21420',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575772},
#  {'address': 'Modemannstraße 16',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 6589,
#     'electric_lock': True,
#     'number': '22282',
#     'state': 'ok'}],
#   'bike_numbers': '22282',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9502018,
#   'lng': 7.017886883,
#   'maintenance': False,
#   'name': 'BIKE 22282',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575785},
#  {'address': 'Pipinstraße 16',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9950,
#     'electric_lock': True,
#     'number': '21470',
#     'state': 'ok'}],
#   'bike_numbers': '21470',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9352438,
#   'lng': 6.9598224,
#   'maintenance': False,
#   'name': 'BIKE 21470',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575786},
#  {'address': 'Kalker Hauptstraße 72',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9957,
#     'electric_lock': True,
#     'number': '21076',
#     'state': 'ok'}],
#   'bike_numbers': '21076',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93725547,
#   'lng': 6.998221333,
#   'maintenance': False,
#   'name': 'BIKE 21076',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575789},
#  {'address': 'Bartholomäus-Schink-Straße',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10316,
#     'electric_lock': True,
#     'number': '21702',
#     'state': 'ok'}],
#   'bike_numbers': '21702',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95223515,
#   'lng': 6.9183538,
#   'maintenance': False,
#   'name': 'BIKE 21702',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575794},
#  {'address': 'Nikolausstraße 136',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 9461,
#     'electric_lock': True,
#     'number': '21639',
#     'state': 'ok'}],
#   'bike_numbers': '21639',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91976298,
#   'lng': 6.92320255,
#   'maintenance': False,
#   'name': 'BIKE 21639',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575800},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10453,
#     'electric_lock': True,
#     'number': '21696',
#     'state': 'ok'}],
#   'bike_numbers': '21696',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96504483,
#   'lng': 6.94355005,
#   'maintenance': False,
#   'name': 'BIKE 21696',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575803},
#  {'address': 'Thielenstraße 2',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10724,
#     'electric_lock': True,
#     'number': '21497',
#     'state': 'ok'}],
#   'bike_numbers': '21497',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.9546419,
#   'lng': 6.9154371,
#   'maintenance': False,
#   'name': 'BIKE 21497',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575814},
#  {'address': 'Heinzelmännchenweg 46',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10741,
#     'electric_lock': True,
#     'number': '21842',
#     'state': 'ok'}],
#   'bike_numbers': '21842',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96270268,
#   'lng': 6.91475485,
#   'maintenance': False,
#   'name': 'BIKE 21842',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575816},
#  {'address': '',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 12235,
#     'electric_lock': True,
#     'number': '22403',
#     'state': 'ok'}],
#   'bike_numbers': '22403',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93747128,
#   'lng': 6.97045645,
#   'maintenance': False,
#   'name': 'BIKE 22403',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575833},
#  {'address': 'Wallstraße 89',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 13916,
#     'electric_lock': True,
#     'number': '22057',
#     'state': 'ok'}],
#   'bike_numbers': '22057',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96405163,
#   'lng': 7.000789933,
#   'maintenance': False,
#   'name': 'BIKE 22057',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575834},
#  {'address': 'Everhardstraße 45',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 7286,
#     'electric_lock': True,
#     'number': '22036',
#     'state': 'ok'}],
#   'bike_numbers': '22036',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94850467,
#   'lng': 6.927033283,
#   'maintenance': False,
#   'name': 'BIKE 22036',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575863},
#  {'address': 'Weyertal 47',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 10819,
#     'electric_lock': True,
#     'number': '22414',
#     'state': 'ok'}],
#   'bike_numbers': '22414',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.92377113,
#   'lng': 6.92695525,
#   'maintenance': False,
#   'name': 'BIKE 22414',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575865},
#  {'address': 'Simrockstraße 34',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10466,
#     'electric_lock': True,
#     'number': '21745',
#     'state': 'ok'}],
#   'bike_numbers': '21745',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94893382,
#   'lng': 6.92351365,
#   'maintenance': False,
#   'name': 'BIKE 21745',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575868},
#  {'address': 'Oskar-Jäger-Straße 99',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10035,
#     'electric_lock': True,
#     'number': '22204',
#     'state': 'ok'}],
#   'bike_numbers': '22204',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.93961573,
#   'lng': 6.909451717,
#   'maintenance': False,
#   'name': 'BIKE 22204',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575875},
#  {'address': 'Teichstraße 71',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 10850,
#     'electric_lock': True,
#     'number': '22138',
#     'state': 'ok'}],
#   'bike_numbers': '22138',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95829975,
#   'lng': 6.902800783,
#   'maintenance': False,
#   'name': 'BIKE 22138',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575879},
#  {'address': 'Dünnwalder Straße 54',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 5426,
#     'electric_lock': True,
#     'number': '21710',
#     'state': 'ok'}],
#   'bike_numbers': '21710',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.96872043,
#   'lng': 7.005822017,
#   'maintenance': False,
#   'name': 'BIKE 21710',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575895},
#  {'address': 'Homburger Straße 17',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 13016,
#     'electric_lock': True,
#     'number': '22297',
#     'state': 'ok'}],
#   'bike_numbers': '22297',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91405445,
#   'lng': 6.947665217,
#   'maintenance': False,
#   'name': 'BIKE 22297',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575896},
#  {'address': 'Höninger Weg 55',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 6397,
#     'electric_lock': True,
#     'number': '21014',
#     'state': 'ok'}],
#   'bike_numbers': '21014',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91905728,
#   'lng': 6.94101205,
#   'maintenance': False,
#   'name': 'BIKE 21014',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575901},
#  {'address': 'Am Altenberger Kreuz 1a',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 7005,
#     'electric_lock': True,
#     'number': '21340',
#     'state': 'ok'}],
#   'bike_numbers': '21340',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91882435,
#   'lng': 6.988917083,
#   'maintenance': False,
#   'name': 'BIKE 21340',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575902},
#  {'address': 'Sigmaringer Straße 7',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 11034,
#     'electric_lock': True,
#     'number': '21773',
#     'state': 'ok'}],
#   'bike_numbers': '21773',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.92306548,
#   'lng': 6.903798167,
#   'maintenance': False,
#   'name': 'BIKE 21773',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575914},
#  {'address': 'Wöhlerstraße 27',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 5434,
#     'electric_lock': True,
#     'number': '21086',
#     'state': 'ok'}],
#   'bike_numbers': '21086',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95661567,
#   'lng': 6.932028133,
#   'maintenance': False,
#   'name': 'BIKE 21086',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575917},
#  {'address': 'Juliusstraße 19a',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 13959,
#     'electric_lock': True,
#     'number': '21656',
#     'state': 'ok'}],
#   'bike_numbers': '21656',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.95149333,
#   'lng': 6.99293885,
#   'maintenance': False,
#   'name': 'BIKE 21656',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575932},
#  {'address': 'Gottesweg 12',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 0,
#     'boardcomputer': 10731,
#     'electric_lock': True,
#     'number': '21427',
#     'state': 'ok'}],
#   'bike_numbers': '21427',
#   'bike_racks': 0,
#   'bike_types': {'undefined': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.91141758,
#   'lng': 6.943469633,
#   'maintenance': False,
#   'name': 'BIKE 21427',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575945},
#  {'address': 'Eupener Straße 62',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 8424,
#     'electric_lock': True,
#     'number': '22122',
#     'state': 'ok'}],
#   'bike_numbers': '22122',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.94052815,
#   'lng': 6.88938065,
#   'maintenance': False,
#   'name': 'BIKE 22122',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575952},
#  {'address': 'Bornheimer Straße 22',
#   'bike': True,
#   'bike_list': [{'active': True,
#     'bike_type': 15,
#     'boardcomputer': 13041,
#     'electric_lock': True,
#     'number': '22096',
#     'state': 'ok'}],
#   'bike_numbers': '22096',
#   'bike_racks': 0,
#   'bike_types': {'15': 1},
#   'bikes': 1,
#   'free_racks': 0,
#   'lat': 50.90727743,
#   'lng': 6.9425587,
#   'maintenance': False,
#   'name': 'BIKE 22096',
#   'number': 0,
#   'place_type': '12',
#   'rack_locks': False,
#   'spot': False,
#   'terminal_type': '',
#   'uid': 5575962}]

# %%
bikes = []
stations = []
for i in bikedata:
    if i["bike"] is True:
        bikes.append(i)
    else:
        stations.append(i)

print(len(bikes))
print(len(stations))
# Out:
# 646
# 21

# %%
for i in stations:
    print(i["name"])
# Out:
# Bahnhof Mühlheim
# Hauptbahnhof
# KVB Hauptverwaltung
# Zülpicher Platz
# Neumarkt
# Uni Köln
# Maritim
# Ebertplatz
# Hans-Böckler-Platz
# Bahnhof Deutz
# Breslauer Platz
# Severinsstrasse
# Wienerplatz
# RTL Picassoplatz
# Uni Mensa
# Chlodwigplatz
# TH Köln Südstadt
# Leonardo Royal Hotel
# Hotel Stadtpalais
# Motel One Mediapark
# Motel One Waidmarkt
